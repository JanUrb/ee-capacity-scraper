# %%
import pandas as pd
import numpy as np

# %%
# TODO: Add last table of pdf manually. 
df =pd.read_csv('tabula-extracted_tables2.csv')

# %%
# First step is renaming some of the columns. Later they will be split. But renaming them now makes them easier to work with.
df = df.rename(columns={'Ny Effekt (kW)': 'Effekt', 'Nr Anläggning Placering D/H I drift': 'Nr',
                   '2013 2014 2015 12mån 12mån Månad Tid Hindertid (tim)': '2013'})
# Tabula extracted some headers as rows. The first step is removing those. 
df = df[df.Ber != 'Ber']
df = df[df.Ber != 'MWh']

# %%
# Now that all headers disguised as rows are deleted, it is time to split the columns.
# Sometimes the Effekt col only has 1 value. In that case, np.NaN is used as default value. 
def split_with_default(effekt_str):
    split_str = effekt_str.split(' ', 1)
    if len(split_str) < 2: 
        a = split_str[0]
        b = np.NAN
    else:
        a, b = split_str
    return pd.Series(dict(hoeg=a, lag=b))

# Add columns to df and remove the old one. 
temp_df = df.Effekt.apply(split_with_default)
df = pd.concat([df, temp_df], axis=1)
del df['Effekt']
df
# Out:
#        Fabrikat                                                 Nr    Ber  \
# 1        Tellus             37 Södra Bäckebo,Ålem G5c 19/41 920225    110
# 2        Vestas           501 Seglaberga I,Laholm C4e 20/24 880927    205
# 3     WindWorld                   15 Snaigsto,Näs I5i 28/31 900202    455
# 4     WindWorld                    16 Tjautet,Näs I5i 28/31 900203    455
# 5     WindWorld                  73 Arendala,Lund C2f 27/40 930522    416
# 6     WindWorld        107 Stureholms gård,Ödåkra C3d 27/41 940801    380
# 7     WindWorld         144 Nygården 4:1,Nygården C9a 27/41 950927    260
# 8        Vestas            34 Vitsippan,Grönhögen G3i 27/30 911210    580
# 9        Vestas                 54 Elmer I,Mosås F10a 27/31 920626    280
# 10       Vestas                  63 Bösarp,Bösarp C1i 27/25 921215    472
# 11       Vestas                65 August,Visingsö E7g 27/31 930107    480
# 12       Vestas       68 Kristinelund 1,Ventlinge G3i 27/31 930109    580
# 13       Vestas       69 Kristinelund 2,Ventlinge G3i 27/31 930109    580
# 14       Vestas       70 Kristinelund 3,Ventlinge G3i 27/31 930109    580
# 15       Vestas                  82 Gumman,Simris E2a 27/32 930923    480
# 16       Vestas                   83 Berta,Simris E2a 27/32 930923    480
# 17       Vestas                  96 Viktor,Simris E2a 27/32 940112    480
# 18       Vestas         97 Almetorps Säteri,Lavad C8e 27/32 940202    320
# 19       Vestas   106 Kristinelund Nord,Ventlinge G3i 27/31 940718    600
# 20       Vestas         111 Hällemöllan 1,Rönnäng A7f 29/32 941021    600
# 21       Vestas             112 Rosendal,Rosendal B5f 27/31 940930    500
# 22       Vestas               113 Elvira,Kistinge C4e 27/31 940623    384
# 23       Vestas     116 Sibylla af Ängholmen,Ängh A7f 29/31 941020    570
# 24       Vestas                 119 Hägvards,Hall J7e 29/31 941215    410
# 25       Vestas       136 Nuntorpsskolan,Brålanda B8i 29/31 950824    325
# 26       Vestas        148 Önaholms Gård 5,Tveta C10b 29/34 951108    417
# 27       Vestas                200 Lunden,Gärdhem B8c 29/30 960701    330
# 28       Vestas               215 Kälvene,Kälvene D7h 29/31 960828    330
# 29       Vestas      235 Kristinelund 5,Ventlinge G3i 27/31 961106    600
# 30       Vestas               241 Månsunen,Gislöv E2a 29/32 970217    525
# ...         ...                                                ...    ...
# 1567     Vestas        1899 Kårehamn 12,Kårehamn H5e 112/80 130807  11000
# 1568     Vestas        1900 Kårehamn 13,Kårehamn H5e 112/80 130807  11000
# 1569     Vestas        1901 Kårehamn 14,Kårehamn H5e 112/80 130807  11000
# 1570     Vestas        1902 Kårehamn 15,Kårehamn H5b 112/80 130807  11000
# 1571     Vestas        1903 Kårehamn 16,Kårehamn H5b 112/80 130807  11000
# 1572     Vestas   1962 Skaveröd-Gurseröd 1,Tanu A9f 112/100 140901   8550
# 1573     Vestas   1963 Skaveröd-Gurseröd 2,Tanu A9f 112/100 140901   8550
# 1574     Vestas   1964 Skaveröd-Gurseröd 3,Tanu A9f 112/100 140901   8550
# 1575     Vestas   1965 Skaveröd-Gurseröd 4,Tanu A9f 112/100 140901   8550
# 1576     Vestas   1966 Skaveröd-Gurseröd 5,Tanu A9f 112/100 140901   8550
# 1577     Vestas   1967 Skaveröd-Gurseröd 6,Tanu A9f 112/100 140901   8550
# 1578     Vestas   1968 Skaveröd-Gurseröd 7,Tanu A9f 112/100 140901   8550
# 1579     Vestas   1969 Skaveröd-Gurseröd 8,Tanu A9f 112/100 140901   8550
# 1580     Vestas   1970 Skaveröd-Gurseröd 11,Tan A9f 112/100 140901   8550
# 1581     Vestas   1971 Skaveröd-Gurseröd 12,Tan A9f 112/100 140901   8550
# 1582     Vestas   1972 Skaveröd-Gurseröd 13,Tan A9f 112/100 140901   8550
# 1583     Vestas  1973 Årjäng NV verk 1,Mölnerud B10i112/100 141101   8700
# 1584     Vestas  1974 Årjäng NV verk 2,Mölnerud B10i112/100 141101   8700
# 1585     Vestas  1975 Årjäng NV verk 3,Mölnerud B10i112/100 141101   8700
# 1586     Vestas  1976 Årjäng NV verk 4,Mölnerud B10i112/100 141101   8700
# 1587     Vestas  1977 Årjäng NV verk 5,Mölnerud B10i112/100 141101   8700
# 1588     Vestas  1978 Årjäng NV verk 6,Mölnerud B10i112/100 141101   8700
# 1589     Vestas  1979 Årjäng NV verk 7,Mölnerud B10i112/100 141101   8700
# 1590     Vestas  1980 Årjäng NV verk 8,Mölnerud B10i112/100 141101   8700
# 1591     Vestas  1981 Årjäng NV verk 9,Mölnerud B10i112/100 141101   8700
# 1592     Vestas   1982 Årjäng SV verk 1,Årjäng B10i 112/100 141101   8900
# 1593     Vestas   1984 Årjäng SV verk 3,Årjäng B10i 112/100 141101   8900
# 1594     Vestas   1985 Årjäng SV verk 4,Årjäng B10i 112/100 141101   8900
# 1595     Vestas   1987 Årjäng SV verk 6,Årjäng B10i 112/100 141101   8900
# 1596     Vestas   1988 Årjäng SV verk 7,Årjäng B10i 112/100 141101   8900
#
#                                       2013  hoeg  lag
# 1                  59 63 67 67 96,1 8 72 0    95   20
# 2              101 116 165 165 100 31 76 0   100  NaN
# 3                      274 235 207 207 100   150  NaN
# 4                 94 231 234 234 100 39 69   150  NaN
# 5                      371 417 133 133 100   150  NaN
# 6                268 320 371 371 100 48 71   150  NaN
# 7                       71 224 150 150 100   150  NaN
# 8            393 511 591 591 95,9 87 92 20   225   50
# 9             203 194 289 289 97,7 47 74 1   225   50
# 10            414 461 507 507 99,2 72 95 1   225   50
# 11          320 324 394 394 84,1 53 63 228   225   50
# 12            545 573 670 670 85,7 93 93 4   225   50
# 13            509 562 645 645 85,1 91 93 0   225   50
# 14          539 566 626 626 85,2 72 73 148   225   50
# 15                    502 529 503 503 99,4   225   50
# 16                    501 475 468 468 96,2   225   50
# 17                    492 518 479 479 98,5   225   50
# 18               211 189 275 275 98,4 40 0   225   50
# 19            476 564 604 604 83,3 85 89 0   225   50
# 20        587 596 672 672 96,5 78 78 79 75   225   50
# 21           389 423 521 521 99,4 72 91 12   225   50
# 22                    303 286 309 309 96,1   225   50
# 23           553 584 709 709 98,4 92 88 23   225   50
# 24                      287 226 89 89 98,1   225   50
# 25          202 223 268 268 91,1 17 35 407   225   50
# 26              365 449 568 568 99 79 85 6   225   50
# 27            234 222 292 292 98,6 47 70 0   225   50
# 28                    264 298 180 180 99,7   225   50
# 29            608 635 711 711 87,2 98 94 0   225   50
# 30            476 537 519 519 92,9 85 93 9   225   50
# ...                                    ...   ...  ...
# 1567   4913 12119 8739 8739 99,5 1640 97 5  3075  NaN
# 1568    4913 12119 8614 8614 99 1609 96 13  3075  NaN
# 1569   4913 12119 8741 8741 99,1 1650 97 0  3075  NaN
# 1570   4913 12119 8711 8711 97,8 1653 97 5  3075  NaN
# 1571  4913 12119 9100 9100 99,4 1670 96 12  3075  NaN
# 1572                  4799 4799 100 1263 0  3075  NaN
# 1573                  4425 4425 100 1208 0  3075  NaN
# 1574                  4640 4640 100 1258 0  3075  NaN
# 1575                  4475 4475 100 1153 0  3075  NaN
# 1576                  4688 4688 100 1236 0  3075  NaN
# 1577                  4774 4774 100 1258 0  3075  NaN
# 1578                  4370 4370 100 1117 0  3075  NaN
# 1579                  5034 5034 100 1290 0  3075  NaN
# 1580                  4534 4534 100 1195 0  3075  NaN
# 1581                  4628 4628 100 1212 0  3075  NaN
# 1582                  4373 4373 100 1145 0  3075  NaN
# 1583                  4769 4769 100 1299 0  3075  NaN
# 1584                  4570 4570 100 1266 0  3075  NaN
# 1585                  4758 4758 100 1301 0  3075  NaN
# 1586                  4491 4491 100 1283 0  3075  NaN
# 1587                  4820 4820 100 1293 0  3075  NaN
# 1588                  4930 4930 100 1338 0  3075  NaN
# 1589                  5039 5039 100 1376 0  3075  NaN
# 1590                  4646 4646 100 1305 0  3075  NaN
# 1591                  4797 4797 100 1302 0  3075  NaN
# 1592                         3369 3369 100  3075  NaN
# 1593                         3508 3508 100  3075  NaN
# 1594                         3645 3645 100  3075  NaN
# 1595                         3649 3649 100  3075  NaN
# 1596                         3510 3510 100  3075  NaN
#
# [1564 rows x 6 columns]

# %%
# Now it is time to split the Nr column into useful parts
# The first part is a number. Probably some kind of id. The second part until the comma is the name of the power plant.
# The part after the comma is the name of the place and then some coordinates that are related to the map provided at the end
# of the pdf. The numbers divided by the slash is called d/h(m) in the pdf. The last number is called I drift
